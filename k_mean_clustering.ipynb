# %%
from sklearn.cluster import KMeans
import numpy as np

# Example data
# np.random.seed(0)
X = np.random.rand(100, 2)

# Number of clusters
k = 3

# Initialize KMeans object
kmeans = KMeans(n_clusters=k)

# Fit KMeans to the data
kmeans.fit(X)

# Get cluster centroids and labels
centroids = kmeans.cluster_centers_
labels = kmeans.labels_

# Print centroids and labels
print("Final centroids:")
print(centroids)
print("Final labels:")
print(labels)
# Out:
# Final centroids:
# [[0.53079199 0.16305589]
#  [0.22477318 0.67757842]
#  [0.75377377 0.63262143]]
# Final labels:
# [2 2 1 1 2 2 2 0 1 2 2 1 1 1 0 1 1 1 2 2 1 0 2 0 0 2 0 0 0 0 0 0 1 0 0 2 2
#  0 0 0 1 1 0 0 2 1 1 0 0 0 0 2 1 2 1 1 0 2 2 2 2 2 1 1 0 2 1 2 2 2 2 1 2 1
#  2 1 1 1 2 0 2 2 2 1 0 0 0 0 1 0 1 0 2 2 0 0 1 2 0 1]

# %%
import matplotlib.pyplot as plt

# Plot data points
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', alpha=0.5, edgecolors='k', label='Data Points')

# Plot cluster centroids
plt.scatter(centroids[:, 0], centroids[:, 1], marker='X', s=200, c='red', label='Centroids')

# Add labels and legend
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('K-means Clustering')
plt.legend()

# Show plot
plt.show()
